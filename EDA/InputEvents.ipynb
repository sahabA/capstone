# %%
import pandas as pd
import matplotlib.pylab as plt
from matplotlib.colors import LinearSegmentedColormap
from matplotlib.lines import Line2D 
import numpy as np
# %matplotlib inline

# %%
inputevents =  pd.read_csv("Downloads\INPUTEVENTS_MV.csv\INPUTEVENTS_MV.csv")

# %%
inputevents.head(10)
# Out:
#    ROW_ID  SUBJECT_ID  HADM_ID  ICUSTAY_ID            STARTTIME  \
# 0     241       27063   139787    223259.0  2133-02-05 06:29:00
# 1     242       27063   139787    223259.0  2133-02-05 05:34:00
# 2     243       27063   139787    223259.0  2133-02-05 05:34:00
# 3     244       27063   139787    223259.0  2133-02-03 12:00:00
# 4     245       27063   139787    223259.0  2133-02-03 12:00:00
# 5     246       27063   139787    223259.0  2133-02-05 05:34:00
# 6     247       27063   139787    223259.0  2133-02-05 05:34:00
# 7     248       27063   139787    223259.0  2133-02-05 09:43:00
# 8     249       27063   139787    223259.0  2133-02-05 09:43:00
# 9     250       27063   139787    223259.0  2133-02-05 05:34:00
#
#                ENDTIME  ITEMID      AMOUNT AMOUNTUOM       RATE      ...       \
# 0  2133-02-05 08:45:00  225166    6.774532       mEq        NaN      ...
# 1  2133-02-05 06:30:00  225944   28.132997        ml  30.142497      ...
# ...

# %%
inputevents.isnull().sum()
# Out:
# ROW_ID                                 0
# SUBJECT_ID                             0
# HADM_ID                                0
# ICUSTAY_ID                          1164
# STARTTIME                              0
# ENDTIME                                0
# ITEMID                                 0
# AMOUNT                                 0
# AMOUNTUOM                              0
# RATE                             1576139
# RATEUOM                          1576139
# STORETIME                              0
# CGID                                   0
# ORDERID                                0
# LINKORDERID                            0
# ORDERCATEGORYNAME                      0
# SECONDARYORDERCATEGORYNAME        983428
# ORDERCOMPONENTTYPEDESCRIPTION          0
# ORDERCATEGORYDESCRIPTION               0
# PATIENTWEIGHT                          0
# TOTALAMOUNT                       534027
# TOTALAMOUNTUOM                    530354
# ISOPENBAG                              0
# ...

# %%
inputevents.PATIENTWEIGHT.mean()
# Out:
# 85.55880738598215

# %%
inputevents.PATIENTWEIGHT.plot()

# %%
inputevents.PATIENTWEIGHT.describe()
# Out:
# count    3.618991e+06
# mean     8.555881e+01
# std      3.132838e+01
# min      1.000000e+00
# 25%      6.840000e+01
# 50%      8.140000e+01
# 75%      9.800000e+01
# max      8.106000e+03
# Name: PATIENTWEIGHT, dtype: float64
